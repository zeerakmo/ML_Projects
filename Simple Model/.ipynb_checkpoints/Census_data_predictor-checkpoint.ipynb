# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn

# %%
census_data = pd.read_csv('Dataset/census-income.data', sep=r'\s*,\s*', engine='python')

# %%
census_data
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
census_data.describe(include='all')
# Out:
#                  age workclass        fnlwgt education  education-num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#             marital-status      occupation relationship   race    sex  \
# ...

# %%
census_data['class'].describe()
# Out:
# count     32561
# unique        2
# top       <=50K
# freq      24720
# Name: class, dtype: object

# %%
census_data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country  class
# 0          2174             0              40  United-States  <=50K
# ...

# %%
census_data = census_data.drop(columns=['fnlwgt',
                                       'education-num'], axis=1)
census_data.head()
# Out:
#    age         workclass  education      marital-status         occupation  \
# 0   39         State-gov  Bachelors       Never-married       Adm-clerical
# 1   50  Self-emp-not-inc  Bachelors  Married-civ-spouse    Exec-managerial
# 2   38           Private    HS-grad            Divorced  Handlers-cleaners
# 3   53           Private       11th  Married-civ-spouse  Handlers-cleaners
# 4   28           Private  Bachelors  Married-civ-spouse     Prof-specialty
#
#     relationship   race     sex  capital-gain  capital-loss  hours-per-week  \
# 0  Not-in-family  White    Male          2174             0              40
# 1        Husband  White    Male             0             0              13
# 2  Not-in-family  White    Male             0             0              40
# 3        Husband  Black    Male             0             0              40
# 4           Wife  Black  Female             0             0              40
#
#   native-country  class
# 0  United-States  <=50K
# ...

# %%
census_data = census_data.dropna()
census_data
# Out:
#        age         workclass   education      marital-status  \
# 0       39         State-gov   Bachelors       Never-married
# 1       50  Self-emp-not-inc   Bachelors  Married-civ-spouse
# 2       38           Private     HS-grad            Divorced
# 3       53           Private        11th  Married-civ-spouse
# 4       28           Private   Bachelors  Married-civ-spouse
# ...    ...               ...         ...                 ...
# 32556   27           Private  Assoc-acdm  Married-civ-spouse
# 32557   40           Private     HS-grad  Married-civ-spouse
# 32558   58           Private     HS-grad             Widowed
# 32559   22           Private     HS-grad       Never-married
# 32560   52      Self-emp-inc     HS-grad  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital-gain  \
# 0           Adm-clerical  Not-in-family  White    Male          2174
# 1        Exec-managerial        Husband  White    Male             0
# ...

# %%
census_data[census_data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [age, workclass, education, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, class]
# Index: []

# %%
from sklearn import preprocessing

label_encoding = preprocessing.LabelEncoder()

census_data['class'] = label_encoding.fit_transform(census_data['class'].astype(str))
census_data.sample(10)
# Out:
#        age  workclass     education      marital-status         occupation  \
# 12583   35    Private       HS-grad            Divorced   Transport-moving
# 10290   54    Private       Masters  Married-civ-spouse    Exec-managerial
# 455     40    Private     Assoc-voc  Married-civ-spouse  Machine-op-inspct
# 24192   34    Private       HS-grad       Never-married       Adm-clerical
# 23292   19    Private          12th       Never-married      Other-service
# 10800   21  State-gov  Some-college       Never-married       Tech-support
# 3358    41    Private       HS-grad  Married-civ-spouse       Adm-clerical
# 8548    26    Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 16099   35    Private       HS-grad  Married-civ-spouse  Handlers-cleaners
# 8589    25    Private     Bachelors       Never-married     Prof-specialty
#
#         relationship                race     sex  capital-gain  capital-loss  \
# ...

# %%
census_data['workclass'] = label_encoding.fit_transform(census_data['workclass'].astype(str))
census_data['education'] = label_encoding.fit_transform(census_data['education'].astype(str))
census_data['marital-status'] = label_encoding.fit_transform(census_data['marital-status'].astype(str))
census_data['occupation'] = label_encoding.fit_transform(census_data['occupation'].astype(str))
census_data['relationship'] = label_encoding.fit_transform(census_data['relationship'].astype(str))
census_data['race'] = label_encoding.fit_transform(census_data['race'].astype(str))
census_data['sex'] = label_encoding.fit_transform(census_data['sex'].astype(str))
census_data['native-country'] = label_encoding.fit_transform(census_data['native-country'].astype(str))

# %%
census_data.sample(10)
# Out:
#        age  workclass  education  marital-status  occupation  relationship  \
# 25855   47          2         12               2          10             0
# 22731   66          0          8               6           0             1
# 20469   30          4          8               0          10             4
# 29959   43          4         11               2           7             0
# 22011   53          7         10               2          10             0
# 3430    50          6          9               2          13             5
# 20292   40          4          9               2           8             5
# 29202   33          4         11               2           3             0
# 13689   40          4         11               4           1             1
# 17830   37          4         15               4          12             1
#
#        race  sex  capital-gain  capital-loss  hours-per-week  native-country  \
# ...

# %%
census_data.describe(include='all')
# Out:
#                 age     workclass     education  marital-status    occupation  \
# count  32561.000000  32561.000000  32561.000000    32561.000000  32561.000000
# mean      38.581647      3.868892     10.298210        2.611836      6.572740
# std       13.640433      1.455960      3.870264        1.506222      4.228857
# min       17.000000      0.000000      0.000000        0.000000      0.000000
# 25%       28.000000      4.000000      9.000000        2.000000      3.000000
# 50%       37.000000      4.000000     11.000000        2.000000      7.000000
# 75%       48.000000      4.000000     12.000000        4.000000     10.000000
# max       90.000000      8.000000     15.000000        6.000000     14.000000
#
#        relationship          race           sex  capital-gain  capital-loss  \
# count  32561.000000  32561.000000  32561.000000  32561.000000  32561.000000
# mean       1.446362      3.665858      0.669205   1077.648844     87.303830
# ...

# %%
census_data_correlation = census_data.corr()
census_data_correlation
# Out:
#                      age  workclass  education  marital-status  occupation  \
# age             1.000000   0.003787  -0.010508       -0.266288   -0.020947
# workclass       0.003787   1.000000   0.023513       -0.064731    0.254892
# education      -0.010508   0.023513   1.000000       -0.038407   -0.021260
# marital-status -0.266288  -0.064731  -0.038407        1.000000   -0.009654
# occupation     -0.020947   0.254892  -0.021260       -0.009654    1.000000
# relationship   -0.263698  -0.090461  -0.010876        0.185451   -0.075607
# race            0.028718   0.049742   0.014131       -0.068013    0.006763
# sex             0.088832   0.095981  -0.027356       -0.129314    0.080296
# capital-gain    0.077674   0.033835   0.030046       -0.043393    0.025505
# capital-loss    0.057775   0.012216   0.016746       -0.034187    0.017987
# hours-per-week  0.068756   0.138962   0.055510       -0.190519    0.080383
# ...

# %%
import seaborn as sns

fig,ax = plt.subplots(figsize = (16,16))
sns.heatmap(census_data_correlation,annot=True)
# Out:
# <AxesSubplot:>

# %%
X = census_data.drop('class',axis = 1)
Y = census_data['class']

# %%
from sklearn import preprocessing

standard_scaler = preprocessing.StandardScaler()

# %%
features_scaled = standard_scaler.fit_transform(X)
features_scaled.shape
# Out:
# (32561, 12)

# %%
features_scaled_df = pd.DataFrame(features_scaled,columns = X.columns)
features_scaled_df.head()
# Out:
#         age  workclass  education  marital-status  occupation  relationship  \
# 0  0.030671   2.150579  -0.335437        0.921634   -1.317809     -0.277805
# 1  0.837109   1.463736  -0.335437       -0.406212   -0.608387     -0.900181
# 2 -0.042642   0.090050   0.181332       -1.734058   -0.135438     -0.277805
# 3  1.057047   0.090050  -2.402511       -0.406212   -0.135438     -0.900181
# 4 -0.775768   0.090050  -0.335437       -0.406212    0.810458      2.211698
#
#        race       sex  capital-gain  capital-loss  hours-per-week  \
# 0  0.393668  0.703071      0.148453      -0.21666       -0.035429
# 1  0.393668  0.703071     -0.145920      -0.21666       -2.222153
# 2  0.393668  0.703071     -0.145920      -0.21666       -0.035429
# 3 -1.962621  0.703071     -0.145920      -0.21666       -0.035429
# 4 -1.962621 -1.422331     -0.145920      -0.21666       -0.035429
#
#    native-country
# 0        0.291569
# 1        0.291569
# 2        0.291569
# 3        0.291569
# ...

# %%
census_data = pd.concat([features_scaled_df, census_data['class']],axis=1).reset_index(drop=True)

census_data.head(10)
# Out:
#         age  workclass  education  marital-status  occupation  relationship  \
# 0  0.030671   2.150579  -0.335437        0.921634   -1.317809     -0.277805
# 1  0.837109   1.463736  -0.335437       -0.406212   -0.608387     -0.900181
# 2 -0.042642   0.090050   0.181332       -1.734058   -0.135438     -0.277805
# 3  1.057047   0.090050  -2.402511       -0.406212   -0.135438     -0.900181
# 4 -0.775768   0.090050  -0.335437       -0.406212    0.810458      2.211698
# 5 -0.115955   0.090050   0.439716       -0.406212   -0.608387      2.211698
# 6  0.763796   0.090050  -1.110590        0.257711    0.337510     -0.277805
# 7  0.983734   1.463736   0.181332       -0.406212   -0.608387     -0.900181
# 8 -0.555830   0.090050   0.439716        0.921634    0.810458     -0.277805
# 9  0.250608   0.090050  -0.335437       -0.406212   -0.608387     -0.900181
#
#        race       sex  capital-gain  capital-loss  hours-per-week  \
# ...

# %%
X = census_data.drop('class',axis=1)
Y=census_data['class']

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state= 0)

# %%
from sklearn.linear_model import LogisticRegression

classifier = LogisticRegression(penalty = 'l2',C=1.0,solver = 'liblinear')

classifier.fit(x_train,y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
model_accuracy = accuracy_score(y_test,y_pred)
mode_precision = precision_score(y_test,y_pred)
model_recall = recall_score(y_test,y_pred)

#how many were correct is accuracy
#how many of this models positive results were correct prescision
#how many of the indi with diabeetes across dataset were corrrectly calssified by model is recall

print(model_accuracy)
print(mode_precision)
print(model_recall)

# %%
print(model_accuracy)
print(mode_precision)
print(model_recall)
# Out:
# 0.8036646534957519
# 0.7047970479704797
# 0.32345469940728194
