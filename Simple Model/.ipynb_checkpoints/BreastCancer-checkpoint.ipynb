# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn

# %%
cancer_data = pd.read_csv('Dataset/breastcancer.csv')
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
cancer_data.describe(include='all')
# Out:
#                   id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count   5.690000e+02       569   569.000000    569.000000      569.000000
# unique           NaN         2          NaN           NaN             NaN
# top              NaN         B          NaN           NaN             NaN
# freq             NaN       357          NaN           NaN             NaN
# mean    3.037183e+07       NaN    14.127292     19.289649       91.969033
# std     1.250206e+08       NaN     3.524049      4.301036       24.298981
# min     8.670000e+03       NaN     6.981000      9.710000       43.790000
# 25%     8.692180e+05       NaN    11.700000     16.170000       75.170000
# 50%     9.060240e+05       NaN    13.370000     18.840000       86.240000
# 75%     8.813129e+06       NaN    15.780000     21.800000      104.100000
# max     9.113205e+08       NaN    28.110000     39.280000      188.500000
#
#           area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# ...

# %%
from sklearn import preprocessing

label_encoding = preprocessing.LabelEncoder()

cancer_data['diagnosis'] = label_encoding.fit_transform(cancer_data['diagnosis'].astype(str))
cancer_data= cancer_data.drop('Unnamed: 32',axis =1)
cancer_data= cancer_data.drop('id',axis =1)

# %%
cancer_data.head()
cancer_data = cancer_data.dropna()

# %%
cancer_data.shape
# Out:
# (569, 31)

# %%
cancer_data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
cancer_data.corr()
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                 1.000000     0.730029      0.415185        0.742636
# radius_mean               0.730029     1.000000      0.323782        0.997855
# texture_mean              0.415185     0.323782      1.000000        0.329533
# perimeter_mean            0.742636     0.997855      0.329533        1.000000
# area_mean                 0.708984     0.987357      0.321086        0.986507
# smoothness_mean           0.358560     0.170581     -0.023389        0.207278
# compactness_mean          0.596534     0.506124      0.236702        0.556936
# concavity_mean            0.696360     0.676764      0.302418        0.716136
# concave points_mean       0.776614     0.822529      0.293464        0.850977
# symmetry_mean             0.330499     0.147741      0.071401        0.183027
# fractal_dimension_mean   -0.012838    -0.311631     -0.076437       -0.261477
# ...

# %%
X=cancer_data.drop('diagnosis',axis =1)
Y = cancer_data['diagnosis']

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=6, whiten=True)
X_reduced = pca.fit_transform(X)

pca.explained_variance_
# Out:
# array([4.43782605e+05, 7.31010006e+03, 7.03833742e+02, 5.46487379e+01,
#        3.98900178e+01, 3.00458768e+00])

# %%
from sklearn import preprocessing

standard_scaler = preprocessing.StandardScaler()

features_scaled = standard_scaler.fit_transform(X)
features_scaled.shape

features_scaled_df = pd.DataFrame(features_scaled, columns = X.columns)
features_scaled_df.head(10)

cancer_data = pd.concat([features_scaled_df,cancer_data['diagnosis']],axis=1).reset_index(drop = True)

# %%
cancer_data.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
X=cancer_data.drop('diagnosis',axis =1)
Y = cancer_data['diagnosis']

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=6, whiten=True)
X_reduced = pca.fit_transform(X)

pca.explained_variance_
# Out:
# array([13.30499079,  5.7013746 ,  2.82291016,  1.98412752,  1.65163324,
#         1.20948224])

# %%
pca.feature_names_in_
# Out:
# array(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se',
#        'smoothness_se', 'compactness_se', 'concavity_se',
#        'concave points_se', 'symmetry_se', 'fractal_dimension_se',
#        'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst',
#        'smoothness_worst', 'compactness_worst', 'concavity_worst',
#        'concave points_worst', 'symmetry_worst',
#        'fractal_dimension_worst'], dtype=object)

# %%
cancer_data_correlation  = cancer_data.corr()

# %%
import seaborn as sns

fig,ax = plt.subplots(figsize = (32,32))
sns.heatmap(cancer_data_correlation,annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split 

x_train,x_test,y_train,y_test = train_test_split(X_reduced,Y,test_size=0.3,random_state=0)

# %%
x_train.shape
# Out:
# (398, 6)

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

n_estimators = [100,150,200,250,300,500]
learn_rates = [0.001,0.01, 0.02, 0.05, 0.1,0.2,0.3]

param_grid = {'n_estimators': n_estimators,
              'learning_rate': learn_rates}

grid_search = GridSearchCV(GradientBoostingClassifier(random_state = 0),param_grid, cv=2, return_train_score=True,verbose = 10)
grid_search.fit(x_train, y_train)

grid_search.best_params_
# Out:
# Fitting 2 folds for each of 42 candidates, totalling 84 fits
# [CV 1/2; 1/42] START learning_rate=0.001, n_estimators=100......................
# [CV 1/2; 1/42] END learning_rate=0.001, n_estimators=100;, score=(train=0.623, test=0.628) total time=   0.1s
# [CV 2/2; 1/42] START learning_rate=0.001, n_estimators=100......................
# [CV 2/2; 1/42] END learning_rate=0.001, n_estimators=100;, score=(train=0.628, test=0.623) total time=   0.0s
# [CV 1/2; 2/42] START learning_rate=0.001, n_estimators=150......................
# [CV 1/2; 2/42] END learning_rate=0.001, n_estimators=150;, score=(train=0.623, test=0.628) total time=   0.1s
# [CV 2/2; 2/42] START learning_rate=0.001, n_estimators=150......................
# [CV 2/2; 2/42] END learning_rate=0.001, n_estimators=150;, score=(train=0.628, test=0.623) total time=   0.1s
# [CV 1/2; 3/42] START learning_rate=0.001, n_estimators=200......................
# ...

# %%
gradient_boosting = GradientBoostingClassifier(learning_rate=grid_search.best_params_['learning_rate'],n_estimators = grid_search.best_params_['n_estimators'])
gradient_boosting.fit(x_train, y_train)
y_pred = gradient_boosting.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score,recall_score
model_accuracy = accuracy_score(y_test,y_pred)
mode_precision = precision_score(y_test,y_pred)
model_recall = recall_score(y_test,y_pred)

#how many were correct is accuracy
#how many of this models positive results were correct prescision
#how many of the indi with diabeetes across dataset were corrrectly calssified by model is recall

print(model_accuracy*100)
print(mode_precision*100)
print(model_recall*100)
# Out:
# 88.30409356725146
# 84.12698412698413
# 84.12698412698413
